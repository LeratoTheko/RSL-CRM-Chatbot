# %% [markdown]
# <a href="https://colab.research.google.com/github/LeratoTheko/RSL-CRM-Chatbot/blob/main/FinalBot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers datasets torch
# Out:
# ...
# INFO: pip is looking at multiple versions of multiprocess to determine which version is compatible with other requirements. This could take a while.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.6/471.6 kB 14.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 8.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 9.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 13.5 MB/s eta 0:00:00
# ...

# %%
import json
import pandas as pd
from datasets import Dataset


data = [
      {
          "input": "How do I apply for a tax refund?",
          "output": "To apply for a tax refund, file your return and indicate the refund option on the form."
      },
      {
          "input": "What should I do if my tax return is audited?",
          "output": "If your tax return is audited, cooperate with the auditors and provide the requested documents."
      },
      {
          "input": "What is the income threshold for tax filing?",
          "output": "The income threshold for tax filing varies; refer to our guidelines for specific amounts."
      },
      {
          "input": "Are there any tax incentives for small businesses?",
          "output": "Small businesses may qualify for tax incentives such as deductions and credits; check our website."
      },
      {
          "input": "How can I dispute a tax assessment?",
          "output": "To dispute a tax assessment, submit a written appeal along with supporting documents."
      },
      {
          "input": "What is the process for changing my tax withholding?",
          "output": "To change your tax withholding, submit a new W-4 form to your employer."
      },
      {
          "input": "Can I get a tax refund if I am unemployed?",
          "output": "You may still qualify for a tax refund if you are unemployed; it depends on your tax situation."
      },
      {
          "input": "How do I obtain a tax identification number?",
          "output": "You can obtain a tax identification number by applying online or at your local tax office."
      },
      {
          "input": "What records should I keep for tax purposes?",
          "output": "Keep records of all income, deductions, and relevant receipts for tax purposes."
      },
      {
          "input": "What are the deadlines for filing corporate taxes?",
          "output": "Corporate tax filing deadlines vary; please consult our corporate tax page for details."
      },
      {
          "input": "How do I register for e-filing?",
          "output": "To register for e-filing, create an account on our website and follow the instructions."
      },
      {
          "input": "Can I amend my tax return after filing?",
          "output": "Yes, you can amend your tax return by filing Form 1040-X with the correct information."
      },
      {
          "input": "What is the difference between a tax credit and a tax deduction?",
          "output": "A tax credit reduces your tax bill directly, while a tax deduction reduces your taxable income."
      },
      {
          "input": "How does tax residency affect my filing requirements?",
          "output": "Tax residency affects your filing requirements; please refer to our residency guidelines."
      },
      {
          "input": "What resources are available for first-time taxpayers?",
          "output": "First-time taxpayers can find resources and guidance on our website and through our helpline."
      },
      {
          "input": "How do I report foreign bank accounts?",
          "output": "Foreign bank accounts must be reported using Form 8938 or FBAR, depending on the amount."
      },
      {
          "input": "Can I file my taxes without all my documents?",
          "output": "You can file taxes without all documents, but it may delay processing; provide what you have."
      },
      {
          "input": "What happens if I receive an incorrect W-2?",
          "output": "If you receive an incorrect W-2, contact your employer to issue a corrected version."
      },
      {
          "input": "How do I access my tax transcripts?",
          "output": "Tax transcripts can be accessed online through our portal or by requesting them by mail."
      },
      {
          "input": "What are the most common tax mistakes?",
          "output": "Common tax mistakes include incorrect personal information and math errors; double-check your forms."
      },
      {
          "input": "How can I prepare for a tax audit?",
          "output": "Prepare for a tax audit by organizing your documents and understanding your tax situation."
      },
      {
          "input": "What are the benefits of filing electronically?",
          "output": "Filing electronically can lead to faster processing times and quicker refunds."
      },
      {
          "input": "How do I find a certified tax professional?",
          "output": "To find a certified tax professional, use our directory or seek recommendations."
      },
      {
          "input": "Are there special considerations for retirees?",
          "output": "Retirees may have different filing requirements; check our guidelines for specific situations."
      },
      {
          "input": "How do I calculate my estimated tax payments?",
          "output": "Calculate estimated tax payments based on your income and deductions using IRS Form 1040-ES."
      },
      {
          "input": "What should I do if I can’t pay my taxes on time?",
          "output": "If you can’t pay your taxes on time, contact us to discuss payment options."
      },
      {
          "input": "How can I update my address with the Revenue Services?",
          "output": "To update your address, log into your account or submit a change of address form."
      },
      {
          "input": "Are there any tax benefits for education expenses?",
          "output": "There are tax benefits for education expenses, including deductions and credits; refer to our resources."
      },
      {
          "input": "How can I ensure my tax return is accurate?",
          "output": "To ensure accuracy, double-check your calculations and consider using tax preparation software."
      },
      {
          "input": "What options are available for tax payment plans?",
          "output": "Tax payment plans are available; contact us to discuss your options."
      },
      {
          "input": "What do I do if I lost my tax documents?",
          "output": "If you lost your tax documents, try to obtain copies from your employer or the IRS."
      },
      {
          "input": "How do I report rental income?",
          "output": "Report rental income on Schedule E of your tax return, along with any associated expenses."
      },
      {
          "input": "What are the tax implications of selling property?",
          "output": "Selling property may have tax implications, including capital gains taxes; consult our guidelines."
      },
      {
          "input": "Can I get help with tax software?",
          "output": "Yes, we provide support for tax software; visit our help page for assistance."
      },
      {
          "input": "How do I file taxes for a trust?",
          "output": "Filing taxes for a trust requires specific forms; refer to our trust tax guidelines."
      },
      {
          "input": "What should I know about state taxes?",
          "output": "State taxes may differ; check your state’s tax agency for specific requirements."
      },
      {
          "input": "How can I check if I am eligible for tax credits?",
          "output": "To check eligibility for tax credits, review the criteria on our website or contact us."
      },
      {
          "input": "What should I do if I have multiple income sources?",
          "output": "If you have multiple income sources, ensure all income is reported on your tax return."
      },
      {
          "input": "How do I report tips and other income?",
          "output": "Report tips and other income on your tax return; keep detailed records of all income received."
      },
      {
          "input": "What are the tax responsibilities of freelancers?",
          "output": "Freelancers have specific tax responsibilities; refer to our self-employment guidelines."
      },
      {
          "input": "How do I prepare for tax season?",
          "output": "To prepare for tax season, gather all necessary documents and consider consulting a tax professional."
      },
      {
          "input": "What is the tax filing deadline?",
          "output": "The tax filing deadline is April 15."
      },
      {
          "input": "How can I check my tax refund status?",
          "output": "You can check your tax refund status online using our refund tracker."
      },
      {
          "input": "What should I do if I owe more taxes than I can pay?",
          "output": "If you owe more than you can pay, you may qualify for a payment plan or request an extension."
      },
      {
          "input": "What are the penalties for filing taxes late?",
          "output": "Penalties for late filing include interest charges and a possible failure-to-file penalty."
      },
      {
          "input": "What forms do I need for self-employed taxes?",
          "output": "Self-employed individuals need to file Schedule SE and may need to make quarterly payments."
      },
      {
          "input": "How do I claim the Earned Income Tax Credit (EITC)?",
          "output": "To claim the EITC, complete Schedule EIC and meet the income eligibility requirements."
      },
      {
          "input": "What should I do if I forgot to report some income?",
          "output": "File an amended return if you forgot to report income, using Form 1040-X."
      },
      {
          "input": "How do I request an extension for filing my taxes?",
          "output": "Request an extension using Form 4868 before the filing deadline to avoid penalties."
      },
      {
          "input": "What happens if I overpay my taxes?",
          "output": "If you overpay your taxes, you will receive a refund for the excess amount."
      },
      {
          "input": "How do I report changes to my financial situation?",
          "output": "Report changes to your financial situation by updating your tax forms as necessary."
      },
      {
          "input": "What tax breaks are available for homeowners?",
          "output": "Homeowners may qualify for tax breaks such as mortgage interest deductions; check our resources."
      },
      {
          "input": "How do I get help with my taxes?",
          "output": "For help with taxes, contact our helpline or visit our assistance page."
      },
      {
          "input": "What should I know about tax credits for childcare expenses?",
          "output": "Childcare expenses may qualify for tax credits; refer to our childcare tax guidelines."
      },
      {
          "input": "How do I report capital gains from stock sales?",
          "output": "Report capital gains from stock sales on Schedule D of your tax return."
      },
      {
          "input": "What is the standard deduction for the current year?",
          "output": "The standard deduction amount varies each year; check our website for current figures."
      },
      {
          "input": "How do I correct a mistake on my tax return?",
          "output": "To correct a mistake, file an amended return using Form 1040-X."
      },
      {
          "input": "What should I do if I suspect tax fraud?",
          "output": "Report suspected tax fraud to the IRS immediately using Form 3949-A."
      },
      {
          "input": "What are the tax implications of receiving an inheritance?",
          "output": "Receiving an inheritance may have tax implications; consult our inheritance tax guidelines."
      },
      {
          "input": "Can I deduct student loan interest?",
          "output": "Yes, you may be able to deduct student loan interest if you meet the eligibility criteria."
      },
      {
          "input": "What should I do if I didn’t receive my refund?",
          "output": "If you didn’t receive your refund, check your refund status online or contact us."
      },
      {
          "input": "How can I verify my income for tax purposes?",
          "output": "Verify your income for tax purposes using pay stubs, W-2s, or tax returns."
      },
      {
          "input": "What is the difference between a 1099 and a W-2?",
          "output": "A 1099 is used for independent contractors, while a W-2 is used for employees."
      },
      {
          "input": "How do I file taxes if I’m living abroad?",
          "output": "If living abroad, you must file taxes using the IRS forms for foreign income."
      },
      {
          "input": "What are the options for tax relief programs?",
          "output": "Tax relief programs are available; contact us to find out more about your options."
      },
      {
          "input": "What is the process for withdrawing retirement funds?",
          "output": "Withdrawing retirement funds may have tax implications; consult our retirement guidelines."
      }
]


# Convert to DataFrame
df = pd.DataFrame(data)

# Create a column with combined input and output
df['text'] = "Q: " + df['input'] + " A: " + df['output']

# Create Hugging Face Dataset
dataset = Dataset.from_pandas(df[['text']])

# %%
from transformers import GPT2Tokenizer, GPT2LMHeadModel, Trainer, TrainingArguments
from datasets import load_dataset

# Load pre-trained GPT-2 model and tokenizer
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
model = GPT2LMHeadModel.from_pretrained('gpt2')

# Set the padding token
tokenizer.pad_token = tokenizer.eos_token  # Use EOS token as the padding token

# Tokenize the dataset
def tokenize_function(examples):
    tokenized = tokenizer(examples['text'], truncation=True, padding='max_length', max_length=512)
    tokenized['labels'] = tokenized['input_ids']  # Set labels to input_ids for language modeling
    return tokenized

# Tokenize the dataset
tokenized_dataset = dataset.map(tokenize_function, batched=True)

# Split the dataset into training and evaluation sets
train_test_split = tokenized_dataset.train_test_split(test_size=0.2)  # 20% for evaluation
train_dataset = train_test_split['train']
eval_dataset = train_test_split['test']

# Set up training arguments
training_args = TrainingArguments(
    output_dir='./results',          # output directory
    evaluation_strategy='epoch',     # evaluation strategy to adopt during training
    logging_dir='./logs',            # Directory for storing logs
    logging_steps=10,                # Log every 10 steps
    learning_rate=2e-5,              # learning rate
    per_device_train_batch_size=2,   # batch size for training
    per_device_eval_batch_size=2,    # batch size for evaluation
    num_train_epochs=3,              # total number of training epochs
    weight_decay=0.01,               # strength of weight decay
    save_steps=500,                  # Save every 500 steps
    save_total_limit=3,              # Keep only the last 3 models
)

# Create a Trainer instance
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=eval_dataset,  # Pass the evaluation dataset here
)

# Fine-tune the model
trainer.train()
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Map:   0%|          | 0/66 [00:00<?, ? examples/s]
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
#     <div>
#
#       <progress value='78' max='78' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [78/78 27:44, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
# ...

# %%
# Evaluate the model
eval_results = trainer.evaluate()
print(eval_results)
# Out:
#     <div>
#
#       <progress value='7' max='7' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [7/7 00:54]
#     </div>
# {'eval_loss': 0.10153836756944656, 'eval_runtime': 67.7292, 'eval_samples_per_second': 0.207, 'eval_steps_per_second': 0.103, 'epoch': 3.0}

# %%
# Save the model and tokenizer
model.save_pretrained('./results')
tokenizer.save_pretrained('./results')
# Out:
# ('./results/tokenizer_config.json',
#  './results/special_tokens_map.json',
#  './results/vocab.json',
#  './results/merges.txt',
#  './results/added_tokens.json')

# %%
import torch
from transformers import GPT2Tokenizer, GPT2LMHeadModel

# Load the fine-tuned model and tokenizer
tokenizer = GPT2Tokenizer.from_pretrained('./results')  # Make sure to point to your fine-tuned model
model = GPT2LMHeadModel.from_pretrained('./results')
model.eval()  # Set the model to evaluation mode

# Function to generate a response
def generate_response(user_input):
    prompt = f"Q: {user_input} A:"
    input_ids = tokenizer.encode(prompt, return_tensors='pt')

    with torch.no_grad():
        output = model.generate(
            input_ids,
            max_length=100,
            num_return_sequences=3,  # Get multiple responses
            pad_token_id=tokenizer.eos_token_id,
            do_sample=True,
            top_k=30,              # Adjust top-k value
            top_p=0.85,            # Adjust top-p value
            temperature=0.9        # Higher temperature for more diversity
        )

    responses = [tokenizer.decode(o, skip_special_tokens=True)[len(prompt):].strip() for o in output]

    return responses  # Return all responses for further processing


# Example usage
user_input = "What is Revenue Services Lesotho?"
#response = generate_response(user_input)

responses = generate_response(user_input)
for idx, response in enumerate(responses):
    print(f"Response {idx + 1}: {response}")
# Out:
# Response 1: Revenue Services Lesotho is an independent tax-exempt organization that provides tax-exempt status to taxpayers.
# Response 2: Revenue Services Lesotho collects revenue for the purpose of supporting our mission to provide access to low-income families and provide services to our members. Revenue Services Lesotho works to provide access to low-income families and ensure that their benefits are available to them.
# Response 3: Revenue Services Lesotho is a tax-exempt nonprofit organization. We collect tax returns and prepare returns using an IRS-approved form.
